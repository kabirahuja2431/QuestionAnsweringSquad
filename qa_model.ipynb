# %%
#@title Default title text
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# Preconfiguring packages ...
# Selecting previously unselected package cron.
# (Reading database ... 18298 files and directories currently installed.)
# Preparing to unpack .../00-cron_3.0pl1-128ubuntu5_amd64.deb ...
# Unpacking cron (3.0pl1-128ubuntu5) ...
# Selecting previously unselected package libapparmor1:amd64.
# Preparing to unpack .../01-libapparmor1_2.11.0-2ubuntu17.1_amd64.deb ...
# Unpacking libapparmor1:amd64 (2.11.0-2ubuntu17.1) ...
# Selecting previously unselected package libdbus-1-3:amd64.
# Preparing to unpack .../02-libdbus-1-3_1.10.22-1ubuntu1_amd64.deb ...
# Unpacking libdbus-1-3:amd64 (1.10.22-1ubuntu1) ...
# Selecting previously unselected package dbus.
# Preparing to unpack .../03-dbus_1.10.22-1ubuntu1_amd64.deb ...
# Unpacking dbus (1.10.22-1ubuntu1) ...
# Selecting previously unselected package dirmngr.
# Preparing to unpack .../04-dirmngr_2.1.15-1ubuntu8_amd64.deb ...
# Unpacking dirmngr (2.1.15-1ubuntu8) ...
# ...

# %%
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-26-294d536e9a71> in <module>()
#       1 import getpass
#       2 get_ipython().system(u'google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL')
# ----> 3 vcode = getpass.getpass()
#       4 get_ipython().system(u'echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}')
#
# /usr/local/lib/python2.7/dist-packages/ipykernel/kernelbase.pyc in getpass(self, prompt, stream)
#     686             self._parent_ident,
#     687             self._parent_header,
# --> 688             password=True,
#     689         )
#     690
#
# /usr/local/lib/python2.7/dist-packages/ipykernel/kernelbase.pyc in _input_request(self, prompt, ident, parent, password)
#     733             except KeyboardInterrupt:
#     734                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 735                 raise KeyboardInterrupt
# ...

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
# !python2 drive/cs224n-win18-squad/code/main_chars.py --experiment_name=RNet_Trans --mode=train
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# This code was developed and tested on TensorFlow 1.4.1. Your TensorFlow version: 1.4.1
# Loading GLoVE vectors from file: drive/cs224n-win18-squad/data/glove.6B.100d.txt
# 100%|████████████████████████████████| 400000/400000 [00:20<00:00, 19857.86it/s]
# Initializing the QAModel...
# (?, 100)
# (?, 100)
# exp_mask_shape (?, 1, 30)
# logits_shape (?, 300, 30)
# exp_mask_shape (?, 1, 300)
# logits_shape (?, 300, 300)
# Blended reps shape (?, 300, 100)
# exp_mask_shape (?, 30)
# logits_shape (?, 30)
# exp_mask_shape (?, 300)
# logits_shape (?, 300)
# (?, 100)
# exp_mask_shape (?, 300)
# logits_shape (?, 300)
# ...

# %%
import nltk
nltk.download('perluniprops')
# Out:
# [nltk_data] Downloading package perluniprops to /content/nltk_data...
# [nltk_data]   Unzipping misc/perluniprops.zip.
# True

# %%
# !python2 drive/cs224n-win18-squad/code/main_chars.py --experiment_name=RNet_Trans --mode=show_examples
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# This code was developed and tested on TensorFlow 1.4.1. Your TensorFlow version: 1.4.1
# Loading GLoVE vectors from file: drive/cs224n-win18-squad/data/glove.6B.100d.txt
# 100%|████████████████████████████████| 400000/400000 [00:19<00:00, 20810.38it/s]
# Initializing the QAModel...
# (?, 100)
# (?, 100)
# exp_mask_shape (?, 1, 30)
# logits_shape (?, 300, 30)
# exp_mask_shape (?, 1, 300)
# logits_shape (?, 300, 300)
# Blended reps shape (?, 300, 100)
# exp_mask_shape (?, 30)
# logits_shape (?, 30)
# exp_mask_shape (?, 300)
# logits_shape (?, 300)
# (?, 100)
# exp_mask_shape (?, 300)
# logits_shape (?, 300)
# ...

# %%
# !pip install tqdm
# Out:
# ...
#     100% |████████████████████████████████| 51kB 1.8MB/s
# ...

# %%
! cd drive/cs224n-win18-squad

# %%
# !./get_started.sh
# Out:
# /bin/sh: 1: ./get_started.sh: not found

# %%
# !ls
# Out:
# datalab  drive

# %%
# !drive/cs224n-win18-squad/./get_started.sh
# Out:
# /bin/sh: 1: drive/cs224n-win18-squad/./get_started.sh: Permission denied

# %%
# !chmod a+x drive/cs224n-win18-squad/get_started.sh

# %%
# !drive/cs224n-win18-squad/./get_started.sh
# Out:
# drive/cs224n-win18-squad/./get_started.sh: line 12: conda: command not found
# drive/cs224n-win18-squad/./get_started.sh: line 15: activate: No such file or directory
# Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# [nltk_data] Downloading package punkt to /content/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package perluniprops to /content/nltk_data...
# [nltk_data]   Package perluniprops is already up-to-date!
# Will download SQuAD datasets to /content/drive/cs224n-win18-squad/data
# Will put preprocessed SQuAD datasets in /content/drive/cs224n-win18-squad/data
# ...
# train-v1.1.json:  13%|██▊                   | 3.80M/30.3M [00:14<01:32, 285kB/s]
# train-v1.1.json: 30.3MB [01:49, 275kB/s]
# File train-v1.1.json successfully loaded
# Train data has 87599 examples total
# ...
# Preprocessing train: 100%|████████████████████| 442/442 [00:54<00:00,  8.07it/s]
# ...

# %%
# !pip install colorama==0.3.9

# %%
# !pip install nltk==3.2.5
# !pip install numpy==1.14.0
# !pip install six==1.11.0
# !pip install tensorflow-gpu==1.4.1  # Change to tensorflow==1.4.1 if you need to run CPU-only tensorflow (e.g. on your laptop)
# !pip install tensorflow-tensorboard==0.4.0
# !pip install tqdm==4.19.5
# Out:
# ...
#     100% |████████████████████████████████| 16.9MB 1.9MB/s
# ...
#   Found existing installation: numpy 1.14.3
#     Uninstalling numpy-1.14.3:
#       Successfully uninstalled numpy-1.14.3
# ...
#     94% |██████████████████████████████▎ | 160.8MB 37.2MB/s eta 0:00:01
#     100% |████████████████████████████████| 170.1MB 126kB/s
# ...
#     100% |████████████████████████████████| 1.7MB 17.0MB/s
# ...
#     100% |████████████████████████████████| 61kB 5.3MB/s
# ...

# %%
# !python2 drive/cs224n-win18-squad/code/main.py --experiment_name=Rnet --mode=train
# Out:
# python2: can't open file 'drive/cs224n-win18-squad/code/main.py': [Errno 2] No such file or directory

# %%
ls
# Out:
# datalab/

# %%
A = [1,2,3]

# %%
import tensorflow as tf

# %%
A = [1,2,3]

# %%
A
# Out:
# [1, 2, 3]

# %%
sess = tf.Session()

# %%
A = tf.constant(5)

# %%
print sess.run(A)
# Out:
# 5

# %%
sess.close()

# %%
# memory footprint support libraries/code
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
 process = psutil.Process(os.getpid())
 print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " I Proc size: " + humanize.naturalsize( process.memory_info().rss))
 print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
# Out:
# ...
# done
#   Stored in directory: /content/.cache/pip/wheels/17/0f/04/b79c006972335e35472c0b835ed52bfc0815258d409f560108
# Successfully built gputil
# ...
# You are using pip version 9.0.3, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# You are using pip version 9.0.3, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# done
#   Stored in directory: /content/.cache/pip/wheels/69/86/6c/f8b8593bc273ec4b0c653d3827f7482bb2001a2781a73b7f44
# Successfully built humanize
# ...
# You are using pip version 9.0.3, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ('Gen RAM Free: 12.7 GB', ' I Proc size: 138.8 MB')
# GPU RAM Free: 11438MB | Used: 1MB | Util   0% | Total 11439MB

# %%
# !kill -9 -1
